# %% [markdown]
# Connected to env1 (Python 3.12.7)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.convert.xml import XML
from lowfat_sergpanf_2025_02_09_vstudioVer import convertTaskCustom
#from tf.advanced.helpers import dm
#from tf.advanced.zipdata import zipAll, addCheckout
#from tf.app import use
#color = {1: "#47edff", 2: "#81ee93", 3: "#eaff47", 4: "#ffcb47", 5: "#ffa647", 6: "#ff7b47", 7: "#ff479d", 8: "#ff4747", 9: "#477eff", 10: "#a647ff"}

# %%
keywordAtts = set(
    """
    case
    class
    number
    gender
    mood
    person
    role
    tense
    type
    voice
    degree
    articular
""".strip().split()
)

trimAtts = set(
    """
    domain
    frame
    gloss
    id
    lemma
    ln
    morph
    normalized
    ref
    referent
    rule
    strong
    subjref
    unicode
""".strip().split()
)

# %%
renameAtts = {
    "Rule": "crule",
    "frame": "framespec",
    "subjref": "subjrefspec",
    "class": "cls",
    "type": "typems",
}

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml="2025-02-05",
    tf="0.0.1"
)
# Out:
# Working in repository sergpanf/LXX-Link in back-end TF.Convert.XML_BackEnd
# XML data version is 2025-02-05 (most recent)
# TF data version is 0.0.1 (explicit new)
# Processing instructions will be ignored

# %%
X.task(check=True)
# Out:
# XML to TF checking: ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/xml/2025-02-05 => ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/report/2025-02-05
# Processing instructions are ignored
# Start folder mt-sync-lxx:
#    1 15-1timothy.xml
# End   folder mt-sync-lxx
#
# 114 info line(s) written to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/report/2025-02-05/elements.txt
# 0 error(s) in 0 file(s) written to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/report/2025-02-05/errors.txt
# 6 tags of which 0 with multiple namespaces written to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/report/2025-02-05/namespaces.txt
# True

# %%
a = 1
X.task(convert=True)
# Out:
# XML to TF converting: ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/xml/2025-02-05 => ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#   0.00s Not all of the warp features otype and oslots are present in
# ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    book, chapter, verse
#    |   SECTION   FEATURES: book, chapter, verse
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   lex-orig-plain       lemma, trailer
#    |      |   lex-translit-plain   lemmatranslit, trailer
#    |      |   text-orig-full       after, before, text
#    |      |   text-orig-plain      text, trailer
#    |      |   text-translit-plain  trailer, translit
#    |      |   text-unaccent-plain  trailer, unaccent
#    |     0.01s OK
#    |     0.00s Following director...
#    1 15-1timothy.xml
# There are no broken references.
# source reading done
#    |     0.54s "delete" actions: 0
#    |     0.54s "edge" actions: 19344
#    |     0.54s "feature" actions: 5716
#    |     0.54s "node" actions: 4128
#    |     0.54s "resume" actions: 0
#    |     0.54s "slot" actions: 1588
#    |     0.55s "terminate" actions: 5716
#    |          1 x "book" node
#    |          6 x "chapter" node
#    |        345 x "clause" node
#    |        794 x "phrase" node
#    |         89 x "sentence" node
#    |       1570 x "subphrase" node
#    |        113 x "verse" node
#    |       1210 x "wg" node
#    |       1588 x "word" node  = slot type
#    |       5716 nodes of all types
#    |     0.56s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.01s OK
#    |     0.00s reordering nodes ...
#    |     0.00s Sorting 1588 slots (node type "word")
#    |     0.01s Sorting 1 nodes of type "book"
#    |     0.01s Sorting 6 nodes of type "chapter"
#    |     0.01s Sorting 345 nodes of type "clause"
#    |     0.01s Sorting 794 nodes of type "phrase"
#    |     0.02s Sorting 89 nodes of type "sentence"
#    |     0.02s Sorting 1570 nodes of type "subphrase"
#    |     0.03s Sorting 113 nodes of type "verse"
#    |     0.03s Sorting 1210 nodes of type "wg"
#    |     0.03s Max node = 5716
#    |     0.03s OK
#    |     0.00s reassigning feature values ...
#    |      |   node feature "after" with 3176 nodes
#    |      |   node feature "articular" with 412 nodes
#    |      |   node feature "before" with 2 nodes
#    |      |   node feature "book" with 5716 nodes
#    |      |   node feature "bookshort" with 5597 nodes
#    |      |   node feature "case" with 1926 nodes
#    |      |   node feature "chapter" with 5715 nodes
#    |      |   node feature "clausetype" with 144 nodes
#    |      |   node feature "cls" with 4912 nodes
#    |      |   node feature "cltype" with 68 nodes
#    |      |   node feature "criticalsign" with 4 nodes
#    |      |   node feature "crule" with 102 nodes
#    |      |   node feature "degree" with 28 nodes
#    |      |   node feature "discontinuous" with 156 nodes
#    |      |   node feature "domain" with 2280 nodes
#    |      |   node feature "framespec" with 534 nodes
#    |      |   node feature "function" with 2102 nodes
#    |      |   node feature "gender" with 1868 nodes
#    |      |   node feature "gloss" with 3176 nodes
#    |      |   node feature "id" with 3176 nodes
#    |      |   node feature "junction" with 130 nodes
#    |      |   node feature "lang" with 1 node
#    |      |   node feature "lemma" with 3176 nodes
#    |      |   node feature "lemmatranslit" with 3176 nodes
#    |      |   node feature "ln" with 2280 nodes
#    |      |   node feature "mood" with 596 nodes
#    |      |   node feature "morph" with 3176 nodes
#    |      |   node feature "nodeid" with 102 nodes
#    |      |   node feature "normalized" with 3176 nodes
#    |      |   node feature "num" with 5597 nodes
#    |      |   node feature "number" with 2280 nodes
#    |      |   node feature "person" with 354 nodes
#    |      |   node feature "punctuation" with 598 nodes
#    |      |   node feature "ref" with 3176 nodes
#    |      |   node feature "referent" with 174 nodes
#    |      |   node feature "role" with 1764 nodes
#    |      |   node feature "rule" with 2116 nodes
#    |      |   node feature "sp" with 3176 nodes
#    |      |   node feature "strong" with 3176 nodes
#    |      |   node feature "subjrefspec" with 384 nodes
#    |      |   node feature "tense" with 596 nodes
#    |      |   node feature "text" with 3176 nodes
#    |      |   node feature "trailer" with 3176 nodes
#    |      |   node feature "trans" with 3176 nodes
#    |      |   node feature "translit" with 3176 nodes
#    |      |   node feature "typ" with 1054 nodes
#    |      |   node feature "typems" with 1428 nodes
#    |      |   node feature "unaccent" with 3176 nodes
#    |      |   node feature "unicode" with 3176 nodes
#    |      |   node feature "variant" with 2 nodes
#    |      |   node feature "verse" with 5709 nodes
#    |      |   node feature "voice" with 596 nodes
#    |      |   edge feature "frame" with 267 start nodes
#    |      |   edge feature "parent" with 4026 start nodes
#    |      |   edge feature "sibling" with 1909 start nodes
#    |      |   edge feature "subjref" with 192 start nodes
#    |     0.08s OK
#   0.71s Features ready to write
#   0.00s Exporting 53 node and 5 edge and 1 configuration features to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1:
#   0.00s VALIDATING oslots feature
#   0.00s VALIDATING oslots feature
#   0.00s maxSlot=       1588
#   0.00s maxNode=       5716
#   0.01s OK: oslots is valid
#    |     0.04s T after                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T articular            to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T before               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.05s T book                 to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T bookshort            to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T case                 to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T chapter              to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.02s T clausetype           to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T cls                  to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.14s T cltype               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T criticalsign         to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T crule                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.02s T degree               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.02s T discontinuous        to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T domain               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T framespec            to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T function             to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T gender               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T gloss                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T id                   to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T junction             to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T lang                 to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T lemma                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T lemmatranslit        to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T ln                   to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.06s T mood                 to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.07s T morph                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.06s T nodeid               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T normalized           to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.08s T num                  to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.07s T number               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.14s T otype                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.02s T person               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T punctuation          to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T ref                  to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.06s T referent             to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.07s T role                 to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.05s T rule                 to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T sp                   to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T strong               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.14s T subjrefspec          to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T tense                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.06s T text                 to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.05s T trailer              to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.15s T trans                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T translit             to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T typ                  to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T typems               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s T unaccent             to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.15s T unicode              to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.28s T variant              to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.04s T verse                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.06s T voice                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.05s T frame                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.07s T oslots               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.21s T parent               to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.09s T sibling              to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.02s T subjref              to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.03s M otext                to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#   3.40s Exported 53 node features and 5 edge features and 1 config features to ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
# True

# %%
X.task(load=True)

# # %%
X.task(app=True)
# Out:
#    |     0.07s T otype                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.16s T oslots               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.07s T lemma                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.08s T text                 from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.19s T translit             from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.06s T unaccent             from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.07s T verse                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.16s T trailer              from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.19s T chapter              from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.17s T lemmatranslit        from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.16s T book                 from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.10s T after                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |     0.05s T before               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.04s C __levels__           from otype, oslots, otext
#    |      |     0.08s C __order__            from otype, oslots, __levels__
#    |      |     0.02s C __rank__             from otype, __order__
#    |      |     0.27s C __levUp__            from otype, oslots, __rank__
#    |      |     0.14s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.04s C __characters__       from otext
#    |      |     0.11s C __boundary__         from otype, oslots, __rank__
#    |      |     0.05s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, book, chapter, verse
#    |      |     0.05s T articular            from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.10s T bookshort            from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.09s T case                 from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T clausetype           from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.10s T cls                  from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.05s T cltype               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.13s T criticalsign         from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.04s T crule                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.04s T degree               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.04s T discontinuous        from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.15s T domain               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.05s T frame                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.12s T framespec            from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.21s T function             from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T gender               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T gloss                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.07s T id                   from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.05s T junction             from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.03s T lang                 from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T ln                   from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.04s T mood                 from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T morph                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.03s T nodeid               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T normalized           from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.07s T num                  from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.05s T number               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.10s T parent               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T person               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.05s T punctuation          from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.11s T ref                  from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.07s T referent             from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.09s T role                 from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.09s T rule                 from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.27s T sibling              from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.13s T sp                   from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.08s T strong               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T subjref              from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T subjrefspec          from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.07s T tense                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.17s T trans                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.06s T typ                  from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.08s T typems               from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.25s T unicode              from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.05s T variant              from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
#    |      |     0.20s T voice                from ~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/tf/0.0.1
# max node = 5716
# App updating ...
# 	~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/app/static/logo.png (copied)
# 	~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/app/static/display.css (created)
# 	~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/app/config.yaml (created)
# 	~/TF.Convert.XML_BackEnd/sergpanf/LXX-Link/app/app.py (deleted)
# Done
# True
