# %% [markdown]
# Connected to env1 (Python 3.12.7)

# %%
# from tf.convert.xml import XML
# from lowfat_sergpanf_2025_02_09_vstudioVer import convertTaskCustom
#from tf.advanced.helpers import dm
#from tf.advanced.zipdata import zipAll, addCheckout
from tf.app import use
#color = {1: "#47edff", 2: "#81ee93", 3: "#eaff47", 4: "#ffcb47", 5: "#ffa647", 6: "#ff7b47", 7: "#ff479d", 8: "#ff4747", 9: "#477eff", 10: "#a647ff"}

# %%
A = use("sergpanf/LXX-Link:clone", backend="TF.Convert.XML_BackEnd", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under h:/My Drive/eduAndrews/_WORK/TF_Projects_VS/tf.convert.xml_backend">~/tf.convert.xml_backend/sergpanf/LXX-Link/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under h:/My Drive/eduAndrews/_WORK/TF_Projects_VS/tf.convert.xml_backend">~/tf.convert.xml_backend/sergpanf/LXX-Link/tf/0.0.1</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.6.3</a>, <a target="_blank" href="https://tf.convert.xml_backend/sergpanf/LXX-Link/blob/main/app" title="sergpanf/LXX-Link app">sergpanf/LXX-Link/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
A.footprint()
# Out:
# # 66 features
#
# feature | members | size in bytes
# --- | --- | ---
# __levUp__ | 5,716 | 2,769,092
# sibling | 1,909 | 1,110,360
# parent | 4,026 | 890,348
# __levDown__ | 4,128 | 617,080
# num | 5,597 | 576,532
# oslots | 3 | 510,508
# book | 5,716 | 455,090
# chapter | 5,715 | 455,012
# verse | 5,709 | 454,844
# bookshort | 5,597 | 451,752
# __boundary__ | 2 | 449,800
# strong | 3,176 | 321,816
# id | 3,176 | 320,636
# ref | 3,176 | 317,337
# unicode | 3,176 | 304,136
# text | 3,176 | 298,936
# normalized | 3,176 | 298,012
# unaccent | 3,176 | 296,828
# cls | 4,912 | 285,745
# gloss | 3,176 | 278,319
# trans | 3,176 | 278,319
# translit | 3,176 | 276,297
# lemma | 3,176 | 274,918
# lemmatranslit | 3,176 | 261,987
# morph | 3,176 | 248,912
# sp | 3,176 | 236,920
# after | 3,176 | 236,702
# trailer | 3,176 | 236,702
# __order__ | 5,716 | 205,816
# ln | 2,280 | 162,903
# domain | 2,280 | 150,870
# rule | 2,116 | 140,199
# number | 2,280 | 137,744
# function | 2,102 | 137,093
# ...

# %%
F.otype.s("error")
# Out:
# ()

# %%
for b in F.otype.s("book"):
    print(f"{b} {A.sectionStrFromNode(b)}")
# Out:
# 1589 I_Timothy

# %%
F.cls.freqList(nodeTypes={"word"})
# Out:
# (('noun', 415),
#  ('verb', 298),
#  ('adj', 202),
#  ('conj', 201),
#  ('det', 158),
#  ('prep', 120),
#  ('pron', 107),
#  ('adv', 81),
#  ('ptcl', 3),
#  ('num', 2),
#  ('intj', 1))

# %%
F.cls.freqList(nodeTypes={"wg"})
# Out:
# (('np', 393), ('cl', 341), ('pp', 124), ('adjp', 10))

# %%
F.cls.freqList(nodeTypes={"clause"})
# Out:
# (('cl', 303),)

# %%
F.cls.freqList(nodeTypes={"phrase"})
# Out:
# (('verb', 292),
#  ('np', 129),
#  ('pp', 101),
#  ('pron', 71),
#  ('adv', 47),
#  ('adj', 42),
#  ('noun', 33),
#  ('adjp', 3))

# %%
# to enalbe the display of nodes correctly, change it
A.displaySetup(withNodes=True, standardFeatures=True, hiddenTypes={"clause", "phrase"}, hideTypes=True)
# currently, will not show all nodes
book = A.nodeFromSectionStr("I_Timothy")
s = L.d(book, otype="sentence")[0]
A.pretty(s)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.sergpanf.org/LXX-Link/I_Timothy/1/1&amp;version=0.0.1" title="Show this on the website" sec="I_Timothy@1:1">I_Timothy@1:1</a></span></div><div class=" children pr-mode"><div class="contnr c2 trm   " ><div class="lbl c2 trm " ><span class="nd">sentence:2735 </span></div></div></div>

# %%
book = A.nodeFromSectionStr("I_Timothy")
s = L.d(book, otype="wg")[0]
A.pretty(s)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.sergpanf.org/LXX-Link/I_Timothy/1/1&amp;version=0.0.1" title="Show this on the website" sec="I_Timothy@1:1">I_Timothy@1:1</a></span></div><div class=" children pr-mode"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:4507 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:4508 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:2824 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1 </span> <span class="txtu">Παῦλος </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:4509 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:4510 </span></div><div class="children hor w
# ...

# %%
# end user mode
results = A.search("""
verse book=I_Timothy
    sentence
        word
""")
A.show(results, end=2, condensed=True, multiFeatures=False, queryFeatures=False, withNodes=False)
# Out:
#   0.01s 813 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
# end user mode
results = A.search("""
verse book=I_Timothy
    sentence
        word
""")
A.show(results, end=2, condensed=True, multiFeatures=True, queryFeatures=False, withNodes=False)
# Out:
#   0.01s 813 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
# end user mode
results = A.search("""
verse book=I_Timothy
    sentence
        word
""")
A.show(results, end=2, condensed=True, multiFeatures=False, queryFeatures=True, withNodes=False)
# Out:
#   0.01s 813 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
# end user mode
results = A.search("""
verse book=I_Timothy
    sentence
        word
""")
A.show(results, end=2, condensed=True, multiFeatures=False, queryFeatures=True, withNodes=True)
# Out:
#   0.01s 813 results
# <p><b>verse</b> <i>1</i>
# ...
